# %% [markdown]
# * That 1st Process of Handling stander data
# --------------
#  * Read Content of that File.
#  * Set Some input Paramter To drop dublicated data records.
#  * Casting DateTime column.
#  * Splite DateTime Columns into 2 Columns(Date and Time).
#  * Save All Files as CSV Files.

# %%
# Load Requairies Packeage::
#---------------------------
import pandas as pd
import numpy as np 
from datetime import datetime as dt
import time
import os 
#-----------------------------------------------
#-----------------------------------------------
# Identify dirction and present Content of path::
#-----------------------------------------------
path = os.path.abspath('') 
print(f"The Path Dirction :: {path}\n----------------\n\nThe Content Path\n--------------------")
files = os.listdir(path)
filelis = []
for file in files :
    if file.endswith('.csv'):
        filelis.append(file)
        print(file)
print(f"=================\nCsv files::\n----------\n{filelis}")
#-----------------------------------------------
#-----------------------------------------------
# load data:
#---------------------
Pyear  = input("Enter The year  of hist date :: ")
Pmonth = input("Enter The Month of hist date :: ")
Pday   = input("Enter The Day   of hist date :: ")
PHour  = input("Enter The Hour  of hist date :: ")
PMins  = input("Enter The Min   of hist date :: ")
Nyear  = input("Enter The Year  of new date  :: ")
Nmonth = input("Enter The Month of new date  :: ")
Nday   = input("Enter The Day   of new date  :: ")
TFPeriod = input("Enter The timeFrameof  data  :: ")
TFs = ["M5", "M15", "M30","1H","1D"]
for tf in TFs:
    if TFPeriod == "5" :
        TFdata = "M5"
    elif TFPeriod == "15" :
        TFdata = "M15"
    elif TFPeriod == "30" :
        TFdata = "M30"
    elif TFPeriod == "H" :
        TFdata = "1H"
    else :
        TFdata = "1D"
foldataname = input("Enter The Folder Name to store data  :: ")
print(f"---------------------------\n Done Thanks for so much my freind \n---------------------------")
os.mkdir(f"{foldataname}")
for fi in filelis :
    df = pd.read_csv(f"{fi}") 
    if fi.startswith('C') or fi.startswith('N'): 
        fileName = fi.split(",")[0].split("_")[2]
    else :
        fileName = fi.split(",")[0].split("_")[1]
    print(fileName)
    #print(f" Columns :: {df.info()} \n===========================\n Infos :: {df.columns}")
    df.drop(df[(df['time'] <= f"{Pyear}-{Pmonth}-{Pday}T{PHour}:{PMins}:00Z")].index, inplace=True) # changeable
    df['time'] = pd.to_datetime(df['time'], errors='coerce' )
    #print(f"{df.info()} \n==================================\n {df}" )
    df = df.assign(Date=df.time.dt.date, Time=df.time.dt.time)
    df.drop("time", axis = 1 , inplace = True)
    df = df[["Date","Time" , "open" , "high" , "low" , "close"]]
    print(f"{df}\n======================================\n")
    #df.to_csv("5Min/DFM-1H-HistData(01-03-2023-YMD).csv" , index=False) # example of Enteries data
    df.to_csv(f"{foldataname}/{fileName}-{TFdata}-HistData({Nday}-{Nmonth}-{Nyear}-YMD).csv" , index=False)
# Out:
# The Path Dirction :: E:\New-Data-Extrac\05-07-2023\15MIN
# ----------------
#
# The Content Path
# --------------------
# CBOT_DL_ZN1!, 15_ef605.csv
# CBOT_DL_ZW1!, 15_b5bfc.csv
# COMEX_DL_GC1!, 15_13f53.csv
# FX_EURUSD, 15_bed12.csv
# FX_GBPUSD, 15_53816.csv
# FX_USDCHF, 15_62e3f.csv
# FX_USDJPY, 15_720cd.csv
# NYMEX_DL_CL1!, 15_93cd0.csv
# TVC_DJI, 15_1f459.csv
# TVC_DXY, 15_0000f.csv
# TVC_US10Y, 15_d346f.csv
# =================
# Csv files::
# ----------
# ['CBOT_DL_ZN1!, 15_ef605.csv', 'CBOT_DL_ZW1!, 15_b5bfc.csv', 'COMEX_DL_GC1!, 15_13f53.csv', 'FX_EURUSD, 15_bed12.csv', 'FX_GBPUSD, 15_53816.csv', 'FX_USDCHF, 15_62e3f.csv', 'FX_USDJPY, 15_720cd.csv', 'NYMEX_DL_CL1!, 15_93cd0.csv', 'TVC_DJI, 15_1f459.csv', 'TVC_DXY, 15_0000f.csv', 'TVC_US10Y, 15_d346f.csv']
# Enter The year  of hist date :: 2023
# Enter The Month of hist date :: 06
# Enter The Day   of hist date :: 02
# Enter The Hour  of hist date :: 20
# Enter The Min   of hist date :: 45
# Enter The Year  of new date  :: 2023
# Enter The Month of new date  :: 07
# Enter The Day   of new date  :: 01
# Enter The timeFrameof  data  :: 15
# Enter The Folder Name to store data  :: 15333333333333
# ---------------------------
#  Done Thanks for so much my freind
# ---------------------------
# ZN1!
#              Date      Time        open        high         low       close
# 9279   2023-06-04  22:00:00  113.734375  113.765625  113.671875  113.765625
# 9280   2023-06-04  22:15:00  113.750000  113.765625  113.734375  113.750000
# 9281   2023-06-04  22:30:00  113.765625  113.765625  113.718750  113.765625
# 9282   2023-06-04  22:45:00  113.765625  113.765625  113.734375  113.734375
# 9283   2023-06-04  23:00:00  113.750000  113.765625  113.718750  113.765625
# ...           ...       ...         ...         ...         ...         ...
# 11311  2023-07-05  08:00:00  111.953125  112.078125  111.953125  112.015625
# 11312  2023-07-05  08:15:00  112.015625  112.031250  111.968750  111.968750
# 11313  2023-07-05  08:30:00  111.984375  112.000000  111.953125  111.968750
# 11314  2023-07-05  08:45:00  111.968750  111.984375  111.953125  111.953125
# 11315  2023-07-05  09:00:00  111.953125  111.984375  111.921875  111.984375
#
# [2037 rows x 6 columns]
# ======================================
#
# ZW1!
#             Date      Time    open    high    low   close
# 7116  2023-06-05  00:00:00  621.50  627.50  621.5  625.50
# 7117  2023-06-05  00:15:00  626.00  628.00  625.0  627.75
# 7118  2023-06-05  00:30:00  628.00  628.00  627.0  627.50
# 7119  2023-06-05  00:45:00  627.25  627.50  626.0  626.50
# 7120  2023-06-05  01:00:00  626.50  626.75  626.0  626.00
# ...          ...       ...     ...     ...    ...     ...
# 8531  2023-07-03  17:15:00  645.25  645.25  642.5  643.75
# 8532  2023-07-03  17:30:00  644.25  645.25  644.0  644.50
# 8533  2023-07-03  17:45:00  644.50  644.75  642.5  642.75
# 8534  2023-07-03  18:00:00  643.00  643.75  641.0  641.50
# 8535  2023-07-03  18:15:00  641.50  641.75  638.0  640.00
#
# [1420 rows x 6 columns]
# ======================================
#
# GC1!
#              Date      Time    open    high     low   close
# 8206   2023-06-04  22:00:00  1962.3  1965.8  1962.3  1965.7
# 8207   2023-06-04  22:15:00  1965.7  1966.0  1965.2  1965.4
# 8208   2023-06-04  22:30:00  1965.4  1965.8  1964.7  1965.6
# 8209   2023-06-04  22:45:00  1965.6  1965.6  1964.8  1964.8
# 8210   2023-06-04  23:00:00  1964.8  1965.9  1964.5  1965.7
# ...           ...       ...     ...     ...     ...     ...
# 10249  2023-07-05  07:45:00  1933.0  1935.1  1932.4  1934.8
# 10250  2023-07-05  08:00:00  1934.7  1935.7  1934.4  1934.5
# 10251  2023-07-05  08:15:00  1934.4  1934.6  1932.6  1933.7
# 10252  2023-07-05  08:30:00  1933.7  1934.6  1933.3  1934.3
# 10253  2023-07-05  08:45:00  1934.3  1934.9  1934.0  1934.5
#
# [2048 rows x 6 columns]
# ======================================
#
# EURUSD
