# %%
import pandas as pd
import cx_Oracle
import datetime
import csv
import time
import sys

# %%
def fetch_data():
    con = cx_Oracle.connect('STOCK/P3rXdM5HbSgQRmCS@10.1.20.41:1521/STOCK')
    print (con.version)
    sql_sectors = """SELECT CASE30_COMPANIES.SYMBOL_CODE , SYMBOLHISTORY.TRADE_VOLUME 
                    from CASE30_COMPANIES LEFT JOIN SYMBOLHISTORY
                    ON CASE30_COMPANIES.SYMBOL_CODE = SYMBOLHISTORY.SYMBOL_CODE """
    cursor = con.cursor()    
    df_sectors = pd.read_sql(sql_sectors, con)
    print("EGX30 Tickers  && It's Trading Volume\n================================================\n")
    print(df_sectors)
fetch_data()
# Out:
# 11.2.0.4.0
# EGX30 Tickers  && It's Trading Volume
# ...
#
#          SYMBOL_CODE  TRADE_VOLUME
# 0       EGS729J1C018        460842
# 1       EGS73541C012      26598110
# 2       EGS743O1C013        307032
# 3       EGS745L1C014       8134435
# 4       EGS95001C011         23932
# ...              ...           ...
# 104972  EGS729J1C018       1283651
# 104973  EGS73541C012      33863911
# 104974  EGS743O1C013        398022
# 104975  EGS745L1C014       8731318
# 104976  EGS95001C011         46101
#
# [104977 rows x 2 columns]

# %%
def fetch_data():
    con = cx_Oracle.connect('STOCK/P3rXdM5HbSgQRmCS@10.1.20.41:1521/STOCK')
    print (con.version)
    sql_sectors = """SELECT EGX30_CAP_SYMBOLS.SYMBOL_CODE , SYMBOLHISTORY.TRADE_VOLUME 
                    from EGX30_CAP_SYMBOLS LEFT JOIN SYMBOLHISTORY
                    ON EGX30_CAP_SYMBOLS.SYMBOL_CODE = SYMBOLHISTORY.SYMBOL_CODE """
    cursor = con.cursor()    
    df_sectors = pd.read_sql(sql_sectors, con)
    print("EGX30-CAP Tickers  && It's Trading Volume\n================================================\n")
    print(df_sectors)
fetch_data()
# Out:
# 11.2.0.4.0
# EGX30-CAP Tickers  && It's Trading Volume
# ...
#
#          SYMBOL_CODE  TRADE_VOLUME
# 0       EGS729J1C018        460842
# 1       EGS73541C012      26598110
# 2       EGS743O1C013        307032
# 3       EGS745L1C014       8134435
# 4       EGS95001C011         23932
# ...              ...           ...
# 104972  EGS729J1C018       1283651
# 104973  EGS73541C012      33863911
# 104974  EGS743O1C013        398022
# 104975  EGS745L1C014       8731318
# 104976  EGS95001C011         46101
#
# [104977 rows x 2 columns]

# %%
def fetch_data():
    con = cx_Oracle.connect('STOCK/P3rXdM5HbSgQRmCS@10.1.20.41:1521/STOCK')
    print (con.version)
    sql_sectors = """SELECT EGX50_SYMBOLS.SYMBOL_CODE , SYMBOLHISTORY.TRADE_VOLUME 
                    from EGX50_SYMBOLS LEFT JOIN SYMBOLHISTORY
                    ON EGX50_SYMBOLS.SYMBOL_CODE = SYMBOLHISTORY.SYMBOL_CODE """
    cursor = con.cursor()    
    df_sectors = pd.read_sql(sql_sectors, con)
    print("EGX50 Tickers  && It's Trading Volume\n================================================\n")
    print(df_sectors)
fetch_data()
# Out:
# 11.2.0.4.0
# EGX50 Tickers  && It's Trading Volume
# ...
#
#          SYMBOL_CODE  TRADE_VOLUME
# 0       EGS70321C012       2462433
# 1       EGS729J1C018        460842
# 2       EGS73541C012      26598110
# 3       EGS743O1C013        307032
# 4       EGS745L1C014       8134435
# ...              ...           ...
# 182261  EGS73541C012      33863911
# 182262  EGS743O1C013        398022
# 182263  EGS745L1C014       8731318
# 182264  EGS75011C014       8340213
# 182265  EGS95001C011         46101
#
# [182266 rows x 2 columns]

# %%
def fetch_data():
    con = cx_Oracle.connect('STOCK/P3rXdM5HbSgQRmCS@10.1.20.41:1521/STOCK')
    print (con.version)
    sql_sectors = """SELECT EGX70_SYMBOLS.SYMBOL_CODE , SYMBOLHISTORY.TRADE_VOLUME 
                    from EGX70_SYMBOLS LEFT JOIN SYMBOLHISTORY
                    ON EGX70_SYMBOLS.SYMBOL_CODE = SYMBOLHISTORY.SYMBOL_CODE """
    cursor = con.cursor()    
    df_sectors = pd.read_sql(sql_sectors, con)
    print("EGX70 Tickers  && It's Trading Volume\n================================================\n")
    print(df_sectors)
fetch_data()
# Out:
# 11.2.0.4.0
# EGX70 Tickers  && It's Trading Volume
# ...
#
#          SYMBOL_CODE  TRADE_VOLUME
# 0       EGS70321C012       2462433
# 1       EGS70431C019       1236431
# 2       EGS70571C012        188260
# 3       EGS74191C015        424552
# 4       EGS75011C014       1082988
# ...              ...           ...
# 258791  EGS70431C019       1199943
# 258792  EGS70571C012        319736
# 258793  EGS74191C015        282424
# 258794  EGS75011C014       8340213
# 258795  EGS78021C010        442799
#
# [258796 rows x 2 columns]

# %%
def fetch_data():
    con = cx_Oracle.connect('STOCK/P3rXdM5HbSgQRmCS@10.1.20.41:1521/STOCK')
    print (con.version)
    sql_sectors = """SELECT EGX100_SYMBOLS.SYMBOL_CODE , SYMBOLHISTORY.TRADE_VOLUME 
                    from EGX100_SYMBOLS LEFT JOIN SYMBOLHISTORY
                    ON EGX100_SYMBOLS.SYMBOL_CODE = SYMBOLHISTORY.SYMBOL_CODE """
    cursor = con.cursor()    
    df_sectors = pd.read_sql(sql_sectors, con)
    print("EGX100 Tickers  && It's Trading Volume\n================================================\n")
    print(df_sectors)
fetch_data()
# Out:
# 11.2.0.4.0
# EGX100 Tickers  && It's Trading Volume
# ...
#
#          SYMBOL_CODE  TRADE_VOLUME
# 0       EGS70321C012       2462433
# 1       EGS70431C019       1236431
# 2       EGS70571C012        188260
# 3       EGS729J1C018        460842
# 4       EGS73541C012      26598110
# ...              ...           ...
# 363768  EGS743O1C013        398022
# 363769  EGS745L1C014       8731318
# 363770  EGS75011C014       8340213
# 363771  EGS78021C010        442799
# 363772  EGS95001C011         46101
#
# [363773 rows x 2 columns]

# %%
def fetch_data():
    con = cx_Oracle.connect('STOCK/P3rXdM5HbSgQRmCS@10.1.20.41:1521/STOCK')
    print (con.version)
    sql_sectors = "SELECT * from CASE30_COMPANIES "
    cursor = con.cursor()    
    df_sectors = pd.read_sql(sql_sectors, con)
    print("EGX30 Companies Tickers \n================================================\n")
    print(df_sectors)
fetch_data()
# Out:
# 11.2.0.4.0
# EGX30 Companies Tickers
# ...
#
#      SYMBOL_CODE                                        SYMBOL_NAME
# 0   EGS39061C014        MISR FRETILIZERS PRODUCTION COMPANY - MOPCO
# 1   EGS65541C012   CAIRO FOR INVESTMENT AND REAL ESTATE DEVELOPMENT
# 2   EGS691S1C011                                      T M G HOLDING
# 3   EGS65571C019                               MEDINET NASR HOUSING
# 4   EGS60121C018              COMMERCIAL INTERNATIONAL BANK (EGYPT)
# 5   EGS69101C011    EGYPTIAN FINANCIAL GROUP-HERMES HOLDING COMPANY
# 6   EGS655L1C012                     PALM HILLS DEVELOPMENT COMPANY
# 7   EGS37091C013                                    EASTERN COMPANY
# 8   EGS60041C018                              CREDIT AGRICOLE EGYPT
# 9   EGS38191C010                               ABOU KIR FERTILIZERS
# 10  EGS3C251C013                                          EZZ STEEL
# 11  EGS512O1C012                                     IBNSINA PHARMA
# ...

# %%
def fetch_data():
    con = cx_Oracle.connect('STOCK/P3rXdM5HbSgQRmCS@10.1.20.41:1521/STOCK')
    print (con.version)
    sql_sectors = "SELECT * from SYMBOLINFO "
    cursor = con.cursor()    
    df_sectors = pd.read_sql(sql_sectors, con)
    print("SYMBOLINFO  Tickers \n====================\n")
    cols = df_sectors.columns
    print(cols)
    for col in cols :
        print(col)
        print('------------------')
        print(df_sectors[col])
        print("==================================\n==================================")
fetch_data()
# Out:
# 11.2.0.4.0
# SYMBOLINFO  Tickers
# ...
#
# Index(['SYMBOL_CODE', 'SYMBOL_TYPE', 'SECTOR_ID', 'ENG_NAME', 'ARB_NAME',
#        'ISIN', 'REUTERS', 'CURRENCY', 'BOND_TYPE', 'LISTED_SHARES',
#        'PAID_SHARES', 'FACE_VALUE', 'COUPON_VALUE', 'COUPON_DATE',
#        'NET_PROFIT', 'NET_PROFIT_DATE', 'EPS', 'PE_RATIO', 'LAST_TRADE_DATE',
#        'DIVIDEND_YIELD_PERC', 'MARKET_CAP', 'OPEN_PRICE'],
#       dtype='object')
# SYMBOL_CODE
# ------------------
# 0      EGB69611S337
# 1      EGB69611S295
# 2      EGB692R1S245
# 3      EGB694K1S299
# 4      EGS67001C015
#            ...
# 484    EGS32221C011
# 485    EGB69671L013
# 486    EGS65591C017
# 487    EGB692C1S317
# 488    EGS3C001C012
# Name: SYMBOL_CODE, Length: 489, dtype: object
# ...
# SYMBOL_TYPE
# ------------------
# 0      214
# 1      214
# 2      214
# 3      214
# 4      210
#       ...
# 484    210
# 485    214
# 486    210
# 487    214
# 488    210
# Name: SYMBOL_TYPE, Length: 489, dtype: object
# ...
# SECTOR_ID
# ------------------
# ...

# %%
def fetch_data():
    con = cx_Oracle.connect('STOCK/P3rXdM5HbSgQRmCS@10.1.20.41:1521/STOCK')
    print (con.version)
    sql_sectors = "SELECT * from EXCHANGE_ACTIVITIES "
    cursor = con.cursor()    
    df_sectors = pd.read_sql(sql_sectors, con)
    print("EXCHANGE_ACTIVITIES   \n====================\n")
    cols = df_sectors.columns
    print(cols)
    print("==============================================================") 
    print("==============================================================") 
    print(df_sectors)
    print("==============================================================")
    print("==============================================================")
    print("==============================================================")
    for col in cols :
        print(col)
        print('------------------')
        print(df_sectors[col])
        print("==================================\n==================================")
    
       
fetch_data()
# Out:
# 11.2.0.4.0
# EXCHANGE_ACTIVITIES
# ...
#
# Index(['DESCRIPTION', 'TRADES', 'VOLUME', 'VALUE', 'SYMBOLS_TRADED',
#        'SEQUENCE'],
#       dtype='object')
# ...
#   DESCRIPTION  TRADES      VOLUME         VALUE  SYMBOLS_TRADED  SEQUENCE
# 0       TOTAL  103047  1545611483  3.379254e+09             205         4
# 1   UNCHANGED    3851   244666469  1.554339e+08              56         3
# 2    ADVANCED   66713   894994374  2.533661e+09              59         1
# 3    DECLINED   32483   405950640  6.901583e+08              91         2
# ...
# DESCRIPTION
# ------------------
# 0        TOTAL
# 1    UNCHANGED
# 2     ADVANCED
# 3     DECLINED
# Name: DESCRIPTION, dtype: object
# ...
# TRADES
# ------------------
# 0    103047
# 1      3851
# 2     66713
# 3     32483
# Name: TRADES, dtype: int64
# ...
# VOLUME
# ------------------
# 0    1545611483
# 1     244666469
# 2     894994374
# 3     405950640
# Name: VOLUME, dtype: int64
# ...
# VALUE
# ------------------
# 0    3.379254e+09
# 1    1.554339e+08
# ...

# %%
def fetch_data():
    con = cx_Oracle.connect('STOCK/P3rXdM5HbSgQRmCS@10.1.20.41:1521/STOCK')
    print (con.version)
    sql_sectors = "SELECT * from TRADES "
    cursor = con.cursor()    
    df_sectors = pd.read_sql(sql_sectors, con)
    print("TRADES   \n====================\n")
    cols = df_sectors.columns
    print(cols)
    print("==============================================================") 
    print("==============================================================") 
    print(df_sectors)
    print("==============================================================") 
    print("==============================================================") 
    print("==============================================================") 
    for col in cols :
        print(col)
        print('------------------')
        print(df_sectors[col])
        print("==================================\n==================================")
fetch_data()
# Out:
# 11.2.0.4.0
# TRADES
# ...
#
# Index(['TRADE_DATE', 'SYMBOL_CODE', 'MARKET_CODE', 'TICKET_NUMBER',
#        'TRADE_PRICE', 'VOLUME_TRADED', 'TRADE_VALUE', 'LE_VALUE', 'EXEC_TIME',
#        'BUY_ORDER_NUMBER', 'SELL_ORDER_NUMBER', 'REC_COUNT', 'REC_SERIAL'],
#       dtype='object')
# ...
#        TRADE_DATE   SYMBOL_CODE MARKET_CODE          TICKET_NUMBER  \
# 0      2023-06-06  EGS65071C010        NOPL  20230606-000157103386
# 1      2023-06-06  EGS92361C012        NOPL  20230606-000157103387
# 2      2023-06-06  EGS65341C017        NOPL  20230606-000157103388
# 3      2023-06-06  EGS65591C017        NOPL  20230606-000157103389
# 4      2023-06-06  EGS65591C017        NOPL  20230606-000157103390
# ...           ...           ...         ...                    ...
# 104361 2023-06-06  EGS67181C015        NOPL  20230606-000157205429
# 104362 2023-06-06  EGS33321C018        NOPL  20230606-000157205430
# 104363 2023-06-06  EGS65591C017        NOPL  20230606-000157205431
# ...

# %%
def fetch_data():
    con = cx_Oracle.connect('STOCK/P3rXdM5HbSgQRmCS@10.1.20.41:1521/STOCK')
    print (con.version)
    sql_sectors = "SELECT * from SYMBOLSUMMARY "
    cursor = con.cursor()    
    df_sectors = pd.read_sql(sql_sectors, con)
    print("Symbols-Summary   \n====================\n")
    cols = df_sectors.columns
    print(cols)
    print("==============================================================") 
    print("==============================================================") 
    print(df_sectors)
    print("==============================================================") 
    print("==============================================================") 
    print("==============================================================") 
    for col in cols :
        print(col)
        print('------------------')
        print(df_sectors[col])
        print("==================================\n==================================")
    
fetch_data()
# Out:
# 11.2.0.4.0
# Symbols-Summary
# ...
#
# Index(['SYMBOL_CODE', 'SYMBOL_TYPE', 'CUM_NUM_TRANSACT', 'CUM_TRADE_VALUE',
#        'CUM_VOLUME', 'LAST_TRADE_PRICE', 'HIGH_PRICE', 'LOW_PRICE',
#        'CLOSE_PRICE', 'REF_PRICE'],
#       dtype='object')
# ...
#       SYMBOL_CODE  SYMBOL_TYPE  CUM_NUM_TRANSACT  CUM_TRADE_VALUE  CUM_VOLUME  \
# 0    EGS3C161C014          210             267.0     3.401898e+06    457360.0
# 1    EGS3C251C013          210            1793.0     4.480157e+07   1232539.0
# 2    EGS3C311C015         1210               NaN              NaN         NaN
# 3    EGS3C4L1C015          210             731.0     5.250577e+06   5826750.0
# 4    EGS3E1E1C013          210             127.0     1.270681e+06    805211.0
# ..            ...          ...               ...              ...         ...
# 484  EGS672I2C014          210               8.0     1.393336e+05     60048.0
# 485  EGS30401C011          210               1.0     7.902100e+02        19.0
# ...

# %%
def fetch_data():
    con = cx_Oracle.connect('STOCK/P3rXdM5HbSgQRmCS@10.1.20.41:1521/STOCK')
    print (con.version)
    sql_sectors = "SELECT * from SYMBOLMARKET "
    cursor = con.cursor()    
    df_sectors = pd.read_sql(sql_sectors, con)
    print("SymbolMArket   \n====================\n")
    cols = df_sectors.columns
    print(cols)
    print("==============================================================") 
    print("==============================================================") 
    print(df_sectors)
    print("==============================================================") 
    print("==============================================================") 
    print("==============================================================") 
    for col in cols :
        print(col)
        print('------------------')
        print(df_sectors[col])
        print("==================================\n==================================")
fetch_data()
# Out:
# 11.2.0.4.0
# SymbolMArket
# ...
#
# Index(['SYMBOL_CODE', 'MARKET_CODE', 'START_DATE', 'END_DATE',
#        'PRIMARY_MARKET', 'SYMBOL_STATUS'],
#       dtype='object')
# ...
#       SYMBOL_CODE MARKET_CODE START_DATE END_DATE PRIMARY_MARKET SYMBOL_STATUS
# 0    EGS73BR1C013        NOPL        NaT     None              Y          None
# 1    EGS69081C023        NOPL        NaT     None              Y          None
# 2    EGB69561S102        CORP        NaT     None              Y          None
# 3    EGB694Y1S277        CORP        NaT     None              Y          None
# 4    EGB694Y1S285        CORP        NaT     None              Y          None
# ..            ...         ...        ...      ...            ...           ...
# 484  EGS681W1C017         SME        NaT     None              Y          None
# 485  EGS922W1C016         SME        NaT     None              Y          None
# 486  EGS07661C019         SME        NaT     None              Y          None
# ...
